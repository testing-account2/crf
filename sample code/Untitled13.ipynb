# %%
import sys
sys.path

sys.path.append("c:/users/sy/appdata/local/programs/python/python36/lib/site-packages")

import PyPDF2

# %%
import sys
sys.path

sys.path.append("c:/users/sy/appdata/local/programs/python/python36/lib/site-packages")

import PyPDF2
import PyPDF2, traceback

 
src = 'c:/users/sy/downloads/acrf.pdf'
 
#src='c:/users/sy/downloads/acrf.pdf'
input1 = PyPDF2.PdfFileReader(open(src, "rb"))
nPages = input1.getNumPages()

for i in range(nPages) :
        page0 = input1.getPage(i)
        try :
            for annot in page0['/Annots'] :
                print (annot.getObject())       # (1)
                print ('')
        except : 
        # there are no annotations on this page
            pass
    
print(npages)
# Out:
# {'/AP': {'/N': IndirectObject(712, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AE=ADVERSE EVENTS', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 G 0 0 0 rg 0 Tc 0 Tw 100 Tz 0 TL 0 Ts 0 Tr /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial,sans-serif 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071742-07'00'", '/NM': 'ea8f1aa5-d860-4460-8568-b4a3e62839b7', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial,sans-serif;font-stretch:normal"><p dir="ltr"><span style="font-family:Arial">AE=ADVERSE EVENTS</span></p></body>', '/Rect': [229.638, 792.602, 473.423, 811.057], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(714, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AETERM', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071241-07'00'", '/NM': 'ea1fbc30-0366-45d0-a349-adc103949100', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AETERM</p></body>', '/Rect': [310.155, 708.194, 367.003, 725.501], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(2363, 0)}, '/C': [0.75, 1, 0.75], '/Contents': 'DM=DEMOGRAPHICS', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 G 0 0 0 rg 0 Tc 0 Tw 100 Tz 0 TL 0 Ts 0 Tr /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial,sans-serif 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518172143-07'00'", '/NM': '0a917302-df76-4c0b-8fc3-b0faa5ee9ff4', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">DM=DEMOGRAPHICS</p></body>', '/Rect': [229.891, 768.744, 472.95, 790.754], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(720, 0)}, '/C': [0.75, 1, 0.75], '/Contents': 'DTHDTC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071441-07'00'", '/NM': '600d5cb2-e17b-4529-a4ed-2bc2d98f012a', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial,sans-serif;font-stretch:normal"><p dir="ltr"><span style="color:#FF0000;font-family:Arial">DTHDTC</span></p></body>', '/Rect': [334.046, 590.95, 398.829, 609.68], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(716, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AELOC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071237-07'00'", '/NM': 'b7b6e2f3-bca9-43f2-b19f-117427a78993', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AELOC</p></body>', '/Rect': [315.459, 674.213, 362.03, 691.52], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4407, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESTDTC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071328-07'00'", '/NM': 'c1358e22-5008-4349-90f1-795dd02fef23', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESTDTC</p></body>', '/Rect': [253.795, 651.337, 317.605, 668.644], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(715, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AEENRTPT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071318-07'00'", '/NM': '53101852-e403-48ec-8ca0-a9ff0cc036fa', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AEENRTPT</p></body>', '/Rect': [228.014, 620.87, 305.338, 639.801], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(719, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AEENDTC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071351-07'00'", '/NM': 'fb3a7ee0-0ade-49e3-9e2e-633fce34b1a5', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AEENDTC</p></body>', '/Rect': [250.889, 592.656, 314.699, 609.267], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(718, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESER', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071451-07'00'", '/NM': '30788de7-ffe9-4f82-b780-ade886561e13', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESER</p></body>', '/Rect': [250.889, 565.488, 314.699, 582.098], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(721, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESDTH', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071510-07'00'", '/NM': 'e1415e07-10a9-4263-8bf6-c9722dea4fd0', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESDTH</p></body>', '/Rect': [251.552, 537.971, 315.362, 554.581], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(713, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESLIFE', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071521-07'00'", '/NM': '3c3a5c33-71b8-4985-af29-919213857aa3', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESLIFE</p></body>', '/Rect': [252.878, 510.786, 316.689, 527.396], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(723, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESHOSP', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071535-07'00'", '/NM': 'b2861e9d-ceb0-4229-b7f0-f38f05b893ac', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESHOSP</p></body>', '/Rect': [251.884, 480.285, 315.694, 496.895], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(728, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESDISAB', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071637-07'00'", '/NM': 'fcaae5d8-602c-442f-9aed-fde25aa8f7b8', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESDISAB</p></body>', '/Rect': [251.552, 456.763, 319.594, 470.704], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(732, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESCONG', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071653-07'00'", '/NM': '843e6533-6ca9-41fb-96af-491a6a6dd410', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESCONG</p></body>', '/Rect': [251.757, 428.827, 319.799, 444.837], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(729, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESMIE', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071817-07'00'", '/NM': 'bee20002-b01c-4053-b9bc-c5cfe8c6119a', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESMIE</p></body>', '/Rect': [251.757, 403.67, 319.799, 419.68], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(724, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AESER', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071831-07'00'", '/NM': 'b5325ca0-c82a-490d-b45b-e516d84865df', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AESER</p></body>', '/Rect': [327.346, 387.425, 395.388, 403.435], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(730, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AEREL', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071840-07'00'", '/NM': 'e757d176-47cf-4816-b851-58b6a7644d17', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AEREL</p></body>', '/Rect': [251.094, 345.653, 319.136, 361.663], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(725, 0)}, '/C': [0.75, 1, 1], '/Contents': 'SUPPAE.QVAL where QNAM=AEEXP', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071928-07'00'", '/NM': 'ded66811-83f9-4fa7-8105-5f7c49639b51', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">SUPPAE.QVAL where QNAM=AEEXP</p></body>', '/Rect': [250.431, 299.95, 467.788, 315.249], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(726, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AEACN', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518071944-07'00'", '/NM': '69c4ae0f-5c98-40d1-86bd-c76275fa29bb', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AEACN</p></body>', '/Rect': [264.024, 247.52, 332.065, 263.53], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(731, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AEACNOTH', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072029-07'00'", '/NM': '019763d6-a02d-4c32-9271-0cbbbc1370fd', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AEACNOTH</p></body>', '/Rect': [306.459, 162.365, 379.269, 176.006], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4406, 0)}, '/C': [0.75, 1, 1], '/Contents': 'SUPPAE.QVAL where QNAM=ACNOTHSP', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072156-07'00'", '/NM': '937c1ae4-5464-4d16-8eed-1ca6831d38d7', '/P': IndirectObject(29, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">SUPPAE.QVAL where QNAM=ACNOTHSP</p></body>', '/Rect': [377.012, 93.1907, 513.87, 123.601], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(738, 0)}, '/C': [0.75, 1, 1], '/Contents': 'AEOUT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072221-07'00'", '/NM': '69c4ae0f-5c98-40d1-86bd-c76275fa29bb', '/P': IndirectObject(35, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">AEOUT</p></body>', '/Rect': [327.346, 785.592, 376.617, 801.602], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(741, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CM=Concomitant Medications', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial,sans-serif 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072336-07'00'", '/NM': 'ea8f1aa5-d860-4460-8568-b4a3e62839b7', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CM=Concomitant Medications</p></body>', '/Rect': [285.225, 769.064, 550.007, 790.326], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(740, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMTRT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072427-07'00'", '/NM': 'ea1fbc30-0366-45d0-a349-adc103949100', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMTRT</p></body>', '/Rect': [243.739, 732.551, 300.587, 749.858], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(742, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMLOC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072437-07'00'", '/NM': '85a2972d-3fd5-4bad-a0ff-641261d0235c', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMLOC</p></body>', '/Rect': [244.093, 701.066, 300.941, 718.373], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(744, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMDOSTXT/CMDOSE', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518072518-07'00'", '/NM': 'b5192768-f8fb-4bd1-aea8-a49edfbccfba', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMDOSTXT/CMDOSE</p></body>', '/Rect': [243.43, 674.578, 383.248, 693.177], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(743, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMDOSU', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072642-07'00'", '/NM': 'd08bbc84-5353-46b7-ab7a-06208e2da263', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMDOSU</p></body>', '/Rect': [174.14, 636.418, 231.483, 653.725], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(747, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMDOSFRQ', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072645-07'00'", '/NM': '3304480f-1046-41fb-92c0-e7b7edf63191', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMDOSFRQ</p></body>', '/Rect': [165.936, 600.647, 244.005, 618.583], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(745, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMROUTE', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072714-07'00'", '/NM': 'b69773ec-dc5d-4bcd-9236-6ef4c47ee590', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMROUTE</p></body>', '/Rect': [168.588, 572.798, 234.391, 586.756], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4405, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMSTDTC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190610192220-07'00'", '/NM': 'beb808f7-565c-4d67-a112-78ca951d0f0e', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMSTDTC</p></body>', '/Rect': [365.337, 547.263, 431.14, 563.273], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(748, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMENDTC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072747-07'00'", '/NM': '5faf80ed-eb8f-413b-b06f-5f362574f0ad', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMENDTC</p></body>', '/Rect': [264.149, 483.9, 329.951, 499.91], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(752, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMENRTPT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072834-07'00'", '/NM': '186adf2a-de80-4a55-8d96-f40026b44756', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMENRTPT</p></body>', '/Rect': [426.929, 512.792, 503.261, 526.101], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(751, 0)}, '/C': [0.75, 1, 1], '/Contents': 'CMINDC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518072854-07'00'", '/NM': '5465b6c0-276b-4b78-8f8e-7d597e95badd', '/P': IndirectObject(46, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">CMINDC</p></body>', '/Rect': [135.847, 460.362, 201.65, 476.372], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(768, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XO=OBJECTIVE OPTHALMIC ASSESSMENTS ', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial,sans-serif 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518073052-07'00'", '/NM': 'ea8f1aa5-d860-4460-8568-b4a3e62839b7', '/P': IndirectObject(68, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XO=OBJECTIVE OPTHALMIC ASSESSMENTS </p></body>', '/Rect': [189.38, 756.465, 591.685, 780.38], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(767, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOORRES when XOTESTCD=CNJRED', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518080008-07'00'", '/NM': 'ea1fbc30-0366-45d0-a349-adc103949100', '/P': IndirectObject(68, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial,sans-serif;font-stretch:normal"><p dir="ltr"><span style="color:#FF0000;font-family:Arial">XOORRES when XOTESTCD=CNJRED</span></p></body>', '/Rect': [65.0123, 624.517, 191.292, 651.726], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(760, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOSTAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518073154-07'00'", '/NM': 'e13ec5fb-39bc-4181-a6e2-1c6ede950f7f', '/P': IndirectObject(68, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOSTAT</p></body>', '/Rect': [253.139, 645.889, 317.091, 662.157], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(765, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOSTAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518073219-07'00'", '/NM': '1553b7d5-12d0-4995-8d1f-356ca9a51272', '/P': IndirectObject(68, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOSTAT</p></body>', '/Rect': [509.079, 648.541, 573.032, 664.809], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(766, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOCAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518073237-07'00'", '/NM': '547e8c5a-6edc-4810-b546-4f3331d09714', '/P': IndirectObject(68, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOCAT</p></body>', '/Rect': [249.16, 709.211, 313.113, 725.479], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(762, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOORRES when XOTESTCD=CNJRED', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080005-07'00'", '/NM': '1b0a2392-460e-4433-951f-1298f3342ceb', '/P': IndirectObject(68, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOORRES when XOTESTCD=CNJRED</p></body>', '/Rect': [334.363, 625.5, 460.643, 652.709], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(759, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOLOC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518080028-07'00'", '/NM': '2a2760c1-0b4d-4179-af52-a274fbaf03fd', '/P': IndirectObject(68, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOLOC</p></body>', '/Rect': [124.505, 683.02, 188.458, 699.288], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(761, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOLOC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080033-07'00'", '/NM': '3e9d7813-82b1-4d9c-8c99-8f268f5f48bd', '/P': IndirectObject(68, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOLOC</p></body>', '/Rect': [377.462, 683.02, 441.415, 699.288], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(2362, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XO=OBJECTIVE OPTHALMIC ASSESSMENTS ', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518171729-07'00'", '/NM': 'ea8f1aa5-d860-4460-8568-b4a3e62839b7', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XO=OBJECTIVE OPTHALMIC ASSESSMENTS </p></body>', '/Rect': [159.717, 767.384, 562.021, 791.298], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(771, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOCAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080106-07'00'", '/NM': '547e8c5a-6edc-4810-b546-4f3331d09714', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOCAT</p></body>', '/Rect': [147.246, 724.108, 211.199, 740.376], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(773, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOLOC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080110-07'00'", '/NM': '2a2760c1-0b4d-4179-af52-a274fbaf03fd', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOLOC</p></body>', '/Rect': [108.457, 704.547, 172.41, 720.816], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(769, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOORRES when XOTESTCD=CRNSEN', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518080240-07'00'", '/NM': 'ea1fbc30-0366-45d0-a349-adc103949100', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOORRES when XOTESTCD=CRNSEN</p></body>', '/Rect': [55.5948, 605.62, 197.26, 633.801], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(774, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOSTAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080134-07'00'", '/NM': 'e13ec5fb-39bc-4181-a6e2-1c6ede950f7f', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOSTAT</p></body>', '/Rect': [215.873, 619.344, 279.825, 635.613], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(772, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOLOC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080117-07'00'", '/NM': '3e6dc004-8f2e-4064-af14-65f6900c8702', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOLOC</p></body>', '/Rect': [373.152, 705.233, 437.105, 721.501], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(775, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOSTAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080129-07'00'", '/NM': 'bcf8b76a-17ae-46cd-9308-a1af8459bd4a', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOSTAT</p></body>', '/Rect': [121.522, 753.967, 185.474, 770.236], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(776, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOORRES when XOTESTCD=CRNSEN', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080250-07'00'", '/NM': '68739dae-79be-4de8-9298-bf0f14614a05', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOORRES when XOTESTCD=CRNSEN</p></body>', '/Rect': [322.029, 603.133, 463.694, 631.314], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(777, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOSTAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518080435-07'00'", '/NM': '78c23455-a756-499b-95b4-b86d21b4b407', '/P': IndirectObject(81, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOSTAT</p></body>', '/Rect': [489.41, 622.488, 553.363, 638.756], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(2507, 0)}, '/C': [0.75, 1, 1], '/Contents': 'DM=DEMOGRAPHICS', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial,sans-serif 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518172420-07'00'", '/NM': 'ea8f1aa5-d860-4460-8568-b4a3e62839b7', '/P': IndirectObject(91, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">DM=DEMOGRAPHICS</p></body>', '/Rect': [289.991, 776.956, 484.199, 800.87], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(2360, 0)}, '/C': [0.75, 1, 1], '/Contents': 'RFICDTC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518171821-07'00'", '/NM': 'bcf8b76a-17ae-46cd-9308-a1af8459bd4a', '/P': IndirectObject(91, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">RFICDTC</p></body>', '/Rect': [250.823, 667.282, 314.775, 683.552], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
# {'/AP': {'/N': IndirectObject(4404, 0)}, '/C': [0.75, 1, 1], '/Contents': 'BRTHDTC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518171912-07'00'", '/NM': '2081b7a0-a26f-4460-af68-a48f9584e512', '/P': IndirectObject(91, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">BRTHDTC</p></body>', '/Rect': [248.529, 595.169, 312.481, 611.438], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(2358, 0)}, '/C': [0.75, 1, 1], '/Contents': 'SEX', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518171912-07'00'", '/NM': 'd0524825-2421-48e7-acc4-2719f4166230', '/P': IndirectObject(91, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">SEX</p></body>', '/Rect': [248.529, 544.61, 312.481, 560.879], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(2357, 0)}, '/C': [0.75, 1, 1], '/Contents': 'ETHNIC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190518171932-07'00'", '/NM': '911fe48c-cf69-4294-8448-27266bf99245', '/P': IndirectObject(91, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial,sans-serif;font-stretch:normal"><p dir="ltr"><span style="color:#FF0000;font-family:Arial">ETHNIC</span></p></body>', '/Rect': [248.529, 508.636, 312.481, 524.905], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(2356, 0)}, '/C': [0.75, 1, 1], '/Contents': 'RACE', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190518171937-07'00'", '/NM': 'f51fca4a-4db1-432d-90f1-0e5fb61403e7', '/P': IndirectObject(91, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">RACE</p></body>', '/Rect': [255.335, 458.077, 319.287, 474.346], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# ...
#
# {'/AP': {'/N': IndirectObject(4217, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XO=OBJECTIVE OPTHALMIC ASSESSMENTS ', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519120738-07'00'", '/NM': 'ea8f1aa5-d860-4460-8568-b4a3e62839b7', '/P': IndirectObject(667, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XO=OBJECTIVE OPTHALMIC ASSESSMENTS </p></body>', '/Rect': [187.591, 750.172, 589.895, 774.087], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4216, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOLOC', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190519120909-07'00'", '/NM': '2a2760c1-0b4d-4179-af52-a274fbaf03fd', '/P': IndirectObject(667, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOLOC</p></body>', '/Rect': [185.135, 685.223, 249.087, 701.491], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4215, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOSTAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190519120913-07'00'", '/NM': '0555d9a5-b171-447b-a896-c793d2261d3e', '/P': IndirectObject(667, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOSTAT</p></body>', '/Rect': [249.341, 628.63, 313.293, 644.898], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4214, 0)}, '/C': [0.75, 1, 1], '/Contents': 'SUPPXO.QVAL when QNAM=CORR', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519120845-07'00'", '/NM': 'f9a0189b-ef91-4b9d-b845-df5373cf281e', '/P': IndirectObject(667, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">SUPPXO.QVAL when QNAM=CORR</p></body>', '/Rect': [295.325, 519.217, 564.409, 540.837], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4213, 0)}, '/C': [0.75, 1, 1], '/Contents': 'SUPPXO.QVAL when QNAM=PINH', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519120906-07'00'", '/NM': 'b422dd02-49b5-4430-bf78-bd89da6b35db', '/P': IndirectObject(667, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">SUPPXO.QVAL when QNAM=PINH</p></body>', '/Rect': [19.9329, 517.63, 289.016, 539.249], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4212, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOSTAT', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190519120919-07'00'", '/NM': '122f8494-9bb4-459a-a30a-6272d527634b', '/P': IndirectObject(667, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOSTAT</p></body>', '/Rect': [510.76, 629.129, 574.712, 645.397], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4211, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOORRES when XOTESTCD=LOGMAR', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121016-07'00'", '/NM': 'e073effe-268c-4399-8cf2-93a670521b08', '/P': IndirectObject(667, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOORRES when XOTESTCD=LOGMAR</p></body>', '/Rect': [6.29683, 617.896, 137.413, 650.009], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4210, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XOORRES when XOTESTCD=LOGMAR', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial 12.0pt; text-align:left; color:#FF0000 ', '/F': 4, '/M': "D:20190519121023-07'00'", '/NM': 'b9648443-6808-4611-b727-834b9c9562d7', '/P': IndirectObject(667, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XOORRES when XOTESTCD=LOGMAR</p></body>', '/Rect': [330.543, 617.518, 461.659, 649.631], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4238, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XS=SUBJECTIVE OPTHALMIC ASSESSMENTS ', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial,sans-serif 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121117-07'00'", '/NM': 'ea8f1aa5-d860-4460-8568-b4a3e62839b7', '/P': IndirectObject(680, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XS=SUBJECTIVE OPTHALMIC ASSESSMENTS </p></body>', '/Rect': [257.929, 744.606, 540.431, 788.216], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4237, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XSORRES/XSSTAT when XSTESTCD=BURNSTNG', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121457-07'00'", '/NM': 'e073effe-268c-4399-8cf2-93a670521b08', '/P': IndirectObject(680, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial,sans-serif;font-stretch:normal"><p dir="ltr"><span style="color:#FF0000;font-family:Arial">XSORRES/XSSTAT when XSTESTCD=BURNSTNG</span></p></body>', '/Rect': [135.658, 245.313, 438.063, 271.264], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4236, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XSORRES/XSSTAT when XSTESTCD=ITCH', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121454-07'00'", '/NM': '75550ae9-63f8-4947-9aca-f561ac2e6b4a', '/P': IndirectObject(680, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial,sans-serif;font-stretch:normal"><p dir="ltr"><span style="color:#FF0000;font-family:Arial">XSORRES/XSSTAT when XSTESTCD=ITCH</span></p></body>', '/Rect': [136.997, 287.671, 439.401, 313.623], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4235, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XSORRES/XSSTAT when XSTESTCD=FBS', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121536-07'00'", '/NM': '23902202-6fcc-4a10-a904-ac4d3a62335d', '/P': IndirectObject(680, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial,sans-serif;font-stretch:normal"><p dir="ltr"><span style="color:#FF0000;font-family:Arial">XSORRES/XSSTAT when XSTESTCD=FBS</span></p></body>', '/Rect': [137.319, 330.694, 439.723, 356.646], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4234, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XSORRES/XSSTAT when XSTESTCD=PAIN', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121505-07'00'", '/NM': '9cd12ee5-6193-4908-b814-f433efef25e4', '/P': IndirectObject(680, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XSORRES/XSSTAT when XSTESTCD=PAIN</p></body>', '/Rect': [139.763, 437.074, 442.168, 463.025], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4233, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XSORRES/XSSTAT when XSTESTCD=ITCH', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121512-07'00'", '/NM': '83e0f8e7-6796-4a75-b1b9-6bc2f76bf155', '/P': IndirectObject(680, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XSORRES/XSSTAT when XSTESTCD=ITCH</p></body>', '/Rect': [139.163, 404.473, 441.568, 430.425], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4232, 0)}, '/C': [0.75, 1, 1], '/Contents': 'XSORRES/XSSTAT when XSTESTCD=BLURVIS', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121541-07'00'", '/NM': 'd90ba665-b8c8-44eb-b7b8-cbb3210bda11', '/P': IndirectObject(680, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">XSORRES/XSSTAT when XSTESTCD=BLURVIS</p></body>', '/Rect': [136.718, 370.029, 439.123, 395.98], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4231, 0)}, '/C': [0.75, 1, 1], '/Contents': 'VS=VITAL SIGNS ', '/CreationDate': "D:20170814084948-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 18 Tf', '/DS': 'font: italic bold Arial,sans-serif 18.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121604-07'00'", '/NM': 'ea8f1aa5-d860-4460-8568-b4a3e62839b7', '/P': IndirectObject(690, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:18.0pt;text-align:left;color:#000000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">VS=VITAL SIGNS </p></body>', '/Rect': [193.119, 757.154, 475.622, 775.945], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
#
# {'/AP': {'/N': IndirectObject(4230, 0)}, '/C': [0.75, 1, 1], '/Contents': 'VSORRES when VSTESTCD=PULSE', '/CreationDate': "D:20170814085540-07'00'", '/DA': '0 0 0 rg /Arial-BoldItalicMT 12 Tf', '/DS': 'font: italic bold Arial,sans-serif 12.0pt; text-align:left; color:#000000 ', '/F': 4, '/M': "D:20190519121640-07'00'", '/NM': '9cd12ee5-6193-4908-b814-f433efef25e4', '/P': IndirectObject(690, 0), '/RC': '<?xml version="1.0"?><body xmlns="http://www.w3.org/1999/xhtml" xmlns:xfa="http://www.xfa.org/schema/xfa-data/1.0/" xfa:APIVersion="Acrobat:17.11.0" xfa:spec="2.0.2"  style="font-size:12.0pt;text-align:left;color:#FF0000;font-weight:bold;font-style:italic;font-family:Arial;font-stretch:normal"><p dir="ltr">VSORRES when VSTESTCD=PULSE</p></body>', '/Rect': [43.5979, 532.705, 346.003, 558.656], '/Subj': 'Text Box', '/Subtype': '/FreeText', '/T': 'ssarangan', '/Type': '/Annot'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4b11fcddf160> in <module>()
#      19             pass
#      20
# ---> 21 print(npages)
#
# NameError: name 'npages' is not defined
