# %%
import sys
sys.path

sys.path.append("c:/users/ssong/appdata/local/programs/python/python37-32/lib/site-packages")

import PyPDF2, traceback
input1 = PyPDF2.PdfFileReader(open('s:/acrf.pdf', "rb"))
npages = input1.getNumPages()

d={'var': [], 'pages': []}
for i in range(npages) :
        page0 = input1.getPage(i)
        try :
            for x in page0['/Annots']:
                print ('varname: %s pages on:%s'%([x.getObject()][0]['/Contents'],i))
                print ('')
               
             
        except : 
        # there are no annotations on this page
            pass
# Out:
# varname: AE=ADVERSE EVENTS pages on:6
#
# varname: AETERM pages on:6
#
# varname: DM=DEMOGRAPHICS pages on:6
#
# varname: DTHDTC pages on:6
#
# varname: AELOC pages on:6
#
# varname: AESTDTC pages on:6
#
# varname: AEENRTPT pages on:6
#
# varname: AEENDTC pages on:6
#
# varname: AESER pages on:6
#
# varname: AESDTH pages on:6
#
# varname: AESLIFE pages on:6
#
# varname: AESHOSP pages on:6
#
# varname: AESDISAB pages on:6
#
# varname: AESCONG pages on:6
#
# varname: AESMIE pages on:6
#
# varname: AESER pages on:6
#
# varname: AEREL pages on:6
#
# varname: SUPPAE.QVAL where QNAM=AEEXP pages on:6
#
# varname: AEACN pages on:6
#
# varname: AEACNOTH pages on:6
#
# varname: SUPPAE.QVAL where QNAM=ACNOTHSP pages on:6
#
# varname: AEOUT pages on:7
#
# varname: CM=Concomitant Medications pages on:9
#
# varname: CMTRT pages on:9
#
# varname: CMLOC pages on:9
#
# varname: CMDOSTXT/CMDOSE pages on:9
#
# varname: CMDOSU pages on:9
#
# varname: CMDOSFRQ pages on:9
#
# varname: CMROUTE pages on:9
#
# varname: CMSTDTC pages on:9
#
# varname: CMENDTC pages on:9
#
# varname: CMENRTPT pages on:9
#
# varname: CMINDC pages on:9
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:13
#
# varname: XOORRES when XOTESTCD=CNJRED pages on:13
#
# varname: XOSTAT pages on:13
#
# varname: XOSTAT pages on:13
#
# varname: XOCAT pages on:13
#
# varname: XOORRES when XOTESTCD=CNJRED pages on:13
#
# varname: XOLOC pages on:13
#
# varname: XOLOC pages on:13
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:15
#
# varname: XOCAT pages on:15
#
# varname: XOLOC pages on:15
#
# varname: XOORRES when XOTESTCD=CRNSEN pages on:15
#
# varname: XOSTAT pages on:15
#
# varname: XOLOC pages on:15
#
# varname: XOSTAT pages on:15
#
# varname: XOORRES when XOTESTCD=CRNSEN pages on:15
#
# varname: XOSTAT pages on:15
#
# varname: DM=DEMOGRAPHICS pages on:16
#
# varname: RFICDTC pages on:16
#
# varname: BRTHDTC pages on:16
#
# varname: SEX pages on:16
#
# varname: ETHNIC pages on:16
#
# varname: RACE pages on:16
#
# varname: SUPPDM.QVAL when QNAM=RACEOTH pages on:16
#
# varname: SC=Subject Characteristics pages on:16
#
# varname: SCORRES when SCTESTCD=IRISCLR pages on:16
#
# varname: SUPPSC.SCORRES when QNAM=SCOTH pages on:16
#
# varname: XS=SUBJECTIVE OPTHALMIC ASSESSMENTS  pages on:18
#
# varname: XSORRES when XSTESTCD=DRCMFT pages on:18
#
# varname: XOSTAT pages on:18
#
# varname: XSTPT pages on:18
#
# varname: XSTPT pages on:18
#
# varname: XSTPT pages on:18
#
# varname: DS=DISPOSITION pages on:21
#
# varname: DSSTDTC pages on:21
#
# varname: DSTERM pages on:21
#
# varname: DM=DEMOGRAPHICS pages on:21
#
# varname: RFENDTC pages on:21
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:23
#
# varname: XOCAT pages on:23
#
# varname: XOLOC pages on:23
#
# varname: XOORRES when XOTESTCD=NASAL pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOLOC pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOSTAT pages on:23
#
# varname: XOORRES when XOTESTCD=TEMPORAL pages on:23
#
# varname: XOORRES when XOTESTCD=CENTRAL pages on:23
#
# varname: XOORRES when XOTESTCD=INFERIOR pages on:23
#
# varname: XOORRES when XOTESTCD=SUPERIOR pages on:23
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:25
#
# varname: XOCAT pages on:25
#
# varname: XOLOC pages on:25
#
# varname: XOLOC pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOORRES when XOTESTCD=NASAL pages on:25
#
# varname: XOORRES when XOTESTCD=TEMPORAL pages on:25
#
# varname: XOORRES when XOTESTCD=CENTRAL pages on:25
#
# varname: XOORRES when XOTESTCD=SUPERIOR pages on:25
#
# varname: XOORRES when XOTESTCD=INFERIOR pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XOSTAT pages on:25
#
# varname: XS=SUBJECTIVE OPTHALMIC ASSESSMENTS  pages on:28
#
# varname: XSORRES when XSTESTCD=OCDIS pages on:28
#
# varname: XOSTAT pages on:28
#
# varname: XSORRES when XSTESTCD=BURN pages on:28
#
# varname: XSORRES when XSTESTCD=DRY pages on:28
#
# varname: XSORRES when XSTESTCD=GRIT pages on:28
#
# varname: XSORRES when XSTESTCD=STING pages on:28
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:30
#
# varname: XOORRES when XOTESTCD=CYTOALL pages on:30
#
# varname: XOLOC pages on:30
#
# varname: IEORRES  pages on:32
#
# varname: SUPPDS.QVAL when QNAM=QEYE pages on:32
#
# varname: SUPPDS.QVAL when QNAM=PKPOP pages on:32
#
# varname: IE=INCLUSION EXCLUSION CRITERIA NOT MET  pages on:32
#
# varname: IE=INCLUSION/EXCLUSION CRITERIA NOT MET  pages on:34
#
# varname: IETESTCD pages on:34
#
# varname: IETEST pages on:34
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:36
#
# varname: XOLOC pages on:36
#
# varname: XOSTAT pages on:36
#
# varname: XOORRES/XOORRESU when XOTESTCD=IOP pages on:36
#
# varname: XOLOC pages on:36
#
# varname: XOSTAT pages on:36
#
# varname: XOORRES/XOORRESU when XOTESTCD=IOP pages on:36
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:37
#
# varname: XOLOC pages on:37
#
# varname: XOORRES when XOTESTCD=LIDMRED pages on:37
#
# varname: XOSTAT pages on:37
#
# varname: XOLOC pages on:37
#
# varname: XOORRES when XOTESTCD=LIDMRED pages on:37
#
# varname: XOSTAT pages on:37
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:39
#
# varname: XOLOC pages on:39
#
# varname: XOCAT pages on:39
#
# varname: XOLOC pages on:39
#
# varname: XOSTAT pages on:39
#
# varname: XOORRES when XOTESTCD=NASAL pages on:39
#
# varname: XOORRES when XOTESTCD=INFNASAL pages on:39
#
# varname: XOORRES when XOTESTCD=SUPNASAL pages on:39
#
# varname: XOORRES when XOTESTCD=INFTEMP pages on:39
#
# varname: XOORRES when XOTESTCD=SUPTEMP pages on:39
#
# varname: SUPPXO.QVAL when QNAM=STAINTM pages on:39
#
# varname: XOORRES when XOTESTCD=TEMPORAL pages on:39
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:42
#
# varname: XOLOC pages on:42
#
# varname: XOCAT pages on:42
#
# varname: XOSTAT pages on:42
#
# varname: XOORRES when XOTESTCD=NASAL pages on:42
#
# varname: XOORRES when XOTESTCD=TEMPORAL pages on:42
#
# varname: XOORRES when XOTESTCD=CENTRAL pages on:42
#
# varname: XOORRES when XOTESTCD=SUPERIOR pages on:42
#
# varname: XOORRES when XOTESTCD=INFERIOR pages on:42
#
# varname: XOLOC pages on:42
#
# varname: MH=MEDICAL HISTORY pages on:47
#
# varname: MHTERM pages on:47
#
# varname: MHLOC pages on:47
#
# varname: MHSTDTC pages on:47
#
# varname: MHENDTC pages on:47
#
# varname: MHENRTPT pages on:47
#
# varname: XS=SUBJECTIVE OPTHALMIC ASSESSMENTS  pages on:50
#
# varname: XSSTAT pages on:50
#
# varname: XSDTC pages on:50
#
# varname: XS=SUBJECTIVE OPTHALMIC ASSESSMENTS  pages on:51
#
# varname: XSSTAT pages on:51
#
# varname: XSORRES when XSTESTCD=OCDIS pages on:51
#
# varname: XSLOC pages on:51
#
# varname: XSLOC pages on:51
#
# varname: XSSTAT pages on:51
#
# varname: XSORRES when XSTESTCD=OCDIS pages on:51
#
# varname: XS=SUBJECTIVE OPTHALMIC ASSESSMENTS  pages on:58
#
# varname: XSLOC pages on:58
#
# varname: XSORRES when XSTESTCD=OCDIS pages on:58
#
# varname: XSLOC pages on:58
#
# varname: XS=SUBJECTIVE OPTHALMIC ASSESSMENTS  pages on:63
#
# varname: XSORRES when XSTESTCD=OSDI01 pages on:63
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:70
#
# varname: XOLOC pages on:70
#
# varname: XOLOC pages on:70
#
# varname: XOSTAT pages on:70
#
# varname: XOORRES when XOTESTCD=POSLIDE pages on:70
#
# varname: LB=LABORATORY RESULTS pages on:72
#
# varname: LBORRES pages on:72
#
# varname: LBREASND pages on:72
#
# varname: LBSTAT pages on:72
#
# varname: DV=DEVIATIONS pages on:74
#
# varname: SUPPDV.QVAL when QNAM=DVSTRF pages on:74
#
# varname: DVSTDTC pages on:74
#
# varname: DVDECOD pages on:74
#
# varname: DVTERM pages on:74
#
# varname: SUPPDV.QVAL when QNAM=DVTERM1 pages on:74
#
# varname: SUPPDV.QVAL when QNAM=DVOTH pages on:74
#
# varname: DS=DISPOSITION pages on:76
#
# varname: SUPPDS.QNAM when QVAL=PKPOP pages on:76
#
# varname: DSSTDTC pages on:76
#
# varname: DM=DEMOGRAPHICS pages on:78
#
# varname: SUBJID pages on:78
#
# varname: SCORRES pages on:78
#
# varname: SUPPDS.QVAL when QNAM=RTKTDT pages on:79
#
# varname: SUPPDS.QVAL when QNAM=RKITDT pages on:79
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:83
#
# varname: XOLOC pages on:83
#
# varname: XOLOC pages on:83
#
# varname: XOORRES/XOSTAT when XOTESTCD=IRIS pages on:83
#
# varname: XOSTAT pages on:83
#
# varname: XOSTAT pages on:83
#
# varname: SUPPXO.QVAL when QNAM=SLQYN pages on:83
#
# varname: SUPPXO.QVAL when QNAM=SLQYN pages on:83
#
# varname: SUPPXO.QVAL when QNAM=XOFIND pages on:83
#
# varname: SUPPXO.QVAL when QNAM=XOFIND pages on:83
#
# varname: XOORRES/XOSTAT when XOTESTCD=ANTCHM pages on:83
#
# varname: XOORRES/XOSTAT when XOTESTCD=LID pages on:83
#
# varname: XOORRES/XOSTAT when XOTESTCD=LENS pages on:83
#
# varname: XOORRES/XOSTAT when XOTESTCD=CONJ pages on:83
#
# varname: XOORRES/XOSTAT when XOTESTCD=CORNEA pages on:83
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:105
#
# varname: XOLOC pages on:105
#
# varname: XOSTAT pages on:105
#
# varname: SUPPXO.QVAL when QNAM=DFQYN pages on:105
#
# varname: SUPPXO.QVAL when QNAM=XOFIND pages on:105
#
# varname: XOORRES/XOSTAT when XOTESTCD=OPTCNERV pages on:105
#
# varname: XOORRES/XOSTAT when XOTESTCD=CHOROID pages on:105
#
# varname: XOORRES/XOSTAT when XOTESTCD=MACULA pages on:105
#
# varname: XOORRES/XOSTAT when XOTESTCD=RETINA pages on:105
#
# varname: XOORRES/XOSTAT when XOTESTCD=VITREOUS pages on:105
#
# varname: XOLOC pages on:105
#
# varname: SUPPXO.QVAL when QNAM=DFQYN pages on:105
#
# varname: XOSTAT pages on:105
#
# varname: XO=OBJECTIVE OPTHALMIC ASSESSMENTS  pages on:111
#
# varname: XOLOC pages on:111
#
# varname: XOSTAT pages on:111
#
# varname: SUPPXO.QVAL when QNAM=CORR pages on:111
#
# varname: SUPPXO.QVAL when QNAM=PINH pages on:111
#
# varname: XOSTAT pages on:111
#
# varname: XOORRES when XOTESTCD=LOGMAR pages on:111
#
# varname: XOORRES when XOTESTCD=LOGMAR pages on:111
#
# varname: XS=SUBJECTIVE OPTHALMIC ASSESSMENTS  pages on:113
#
# varname: XSORRES/XSSTAT when XSTESTCD=BURNSTNG pages on:113
#
# varname: XSORRES/XSSTAT when XSTESTCD=ITCH pages on:113
#
# varname: XSORRES/XSSTAT when XSTESTCD=FBS pages on:113
#
# varname: XSORRES/XSSTAT when XSTESTCD=PAIN pages on:113
#
# varname: XSORRES/XSSTAT when XSTESTCD=ITCH pages on:113
#
# varname: XSORRES/XSSTAT when XSTESTCD=BLURVIS pages on:113
#
# varname: VS=VITAL SIGNS  pages on:114
#
# varname: VSORRES when VSTESTCD=PULSE pages on:114
