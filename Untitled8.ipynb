# %%
import sys
sys.path

sys.path.append("c:/users/sy/appdata/local/programs/python/python36/lib/site-packages")

import pdfminer

from pdfminer.layout import LAParams
from pdfminer.pdfinterp import PDFResourceManager,  PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
#from pdfminer.pdfparser import PDFPage
from pdfminer.pdfparser import PDFDocument
from pdfminer.layout import LTTextBoxHorizontal
document = open('c:/users/sy/downloads/acrf.pdf', 'rb')
#PDFDocument.get_pages(document)

from pdfminer.pdfparser import PDFParser

# %%
#Create resource manager
rsrcmgr = PDFResourceManager()
# Set parameters for analysis.
laparams = LAParams()
# Create a PDF page aggregator object.
device = PDFPageAggregator(rsrcmgr, laparams=laparams)
interpreter = PDFPageInterpreter(rsrcmgr, device)
#for page in PDFPage.get_pages(document):

fp = open('c:/users/sy/downloads/acrf.pdf', 'rb')
parser = PDFParser(fp)
doc = PDFDocument()
parser.set_document(doc)
doc.set_parser(parser)
doc.initialize('')

for page in doc.get_pages():
    
    interpreter.process_page(page)
# receive the LTPage object for the page.
    layout = device.get_result()
    for element in layout:
        #print (element)
        #if isinstance(element, pdfminer.layout.LTTextBox): #Horizontal
        #if isinstance(element, pdfminer.layout.LTFigure,):
        #    pass
        #else:
           # print(element.get_text())
            #print("%s "%(element.get_text()))
            print(element) 
            #print("%s %d"%(element.get_text(),element._avg_lineheight))
            '''
            for o in element._objs:
                if isinstance(o,pdfminer.layout.LTTextLine):
                    text=o.get_text()
                    print(" %s"%(text))
            '''
            '''
                    if text.strip():
                        for c in  o._objs:
                            if isinstance(c, pdfminer.layout.LTChar):
                                print ("text %s fontsize %s"%(c._text,c.size) )
                            else:
                                pass
                    '''
# Out:
# WARNING:root:Cannot locate objid=4399
# <LTFigure(Obj5) 0.000,0.000,586.080,829.200 matrix=[586.08,0.00,0.00,829.20, (0.00,0.00)]>
# <LTFigure(Obj6) 151.680,664.560,412.800,684.720 matrix=[261.12,0.00,0.00,20.16, (151.68,664.56)]>
# <LTFigure(Obj7) 157.440,390.000,422.400,483.600 matrix=[264.96,0.00,0.00,93.60, (157.44,390.00)]>
# <LTTextBoxHorizontal(0) 204.240,693.119,412.317,715.974 'TOP1630-TV-05 CRF Notes \n'>
# <LTTextBoxHorizontal(1) 76.560,633.492,193.385,685.642 'Database Study Name: \nCRF Version Number: \nCRF Version Date: \n'>
# <LTTextBoxHorizontal(2) 229.552,633.492,313.390,685.642 'TOP1630-TV-05 \n1.0 \n31 JAN 2019 \n'>
# <LTTextBoxHorizontal(3) 83.040,600.732,139.267,615.802 'Visit Name \n'>
# <LTTextBoxHorizontal(4) 83.040,398.580,191.736,597.960 'Enrollment \nVisit 1 Pre-CAE(R) \nVisit 1 Post-CAE(R) \nVisit 2 Pre-CAE(R) \nVisit 2 Post-CAE(R) \nVisit 3 Pre-CAE(R) \nVisit 3 Post-CAE(R) \nVisit 4 Pre-CAE(R) \nVisit 4 Post-CAE(R) \nLogs \nEarly Termination \n'>
# ...

# %%
import minecart
pdffile = open('c:/users/sy/downloads/acrf.pdf', 'rb')

doc = minecart.Document(pdffile)
page = doc.get_page(3)
colors=set()
#for shape in page.shapes.iter_in_bbox((0, 0, 100, 200)):
#     print (shape.path)#, shape.fill.color.as_rgb())
for shape in page.shapes:
        if shape.fill:
            colors.add(shape.fill.color.as_rgb())

for color in colors: print (color)
    
#im = page.images[0].as_pil()  # requires pillow
#im.show()
# Out:
# WARNING:root:Cannot locate objid=4399
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-6acd594e29f5> in <module>()
#       9 for shape in page.shapes:
#      10         if shape.fill:
# ---> 11             colors.add(shape.fill.color.as_rgb())
#      12
#      13 for color in colors: print (color)
#
# TypeError: unhashable type: 'list'
